# %% [markdown]
# Section 7 : Searching & Membership

# %% [markdown]
# # ==========================================================
# # SECTION 7 : SEARCHING & MEMBERSHIP
# # ==========================================================
#
# """
# OBJECTIVE
# ---------
# Master searching operations available on Python lists.
#
# By the end of this section, you'll understand:
#
# ✓ in
# ✓ not in
# ✓ index()
# ✓ count()
#
# More importantly,
#
# ✓ Internal working
# ✓ Time Complexity
# ✓ Best Practices
# ✓ Common Pitfalls
# ✓ Interview Patterns
# """

# %%
# syntax
# value in list
# return true or flase

# %%
numbers = [10,20,30,40]

print(20 in numbers)

print(50 in numbers)
# Out:
# True
# False

# %%
fruits = ["Apple","Banana","Mango"]

print("Apple" in fruits)

print("Orange" in fruits)
# Out:
# True
# False

# %%
"""Behind the scenes
for item in numbers:
    if item == target:  
        return True

return False
"""
# Out:
# 'Behind the scenes\nfor item in numbers:\n    if item == target:  \n        return True\n\nreturn False\n'

# %% [markdown]
# TC -> worst case O(n),if element is not present
#
# and O(1) in best case if element is present on the first index

# %% [markdown]
# Part 2 : not in

# %%
numbers = [10,20,30]

print(100 not in numbers)
# Out:
# True

# %%
"""Internally,

Python performs the same search.

It simply negates the result.

Complexity remains"""
# Out:
# 'Internally,\n\nPython performs the same search.\n\nIt simply negates the result.\n\nComplexity remains'

# %% [markdown]
# Part 3 : index()

# %%
numbers = [10,20,30,40]

print(numbers.index(30))
# Out:
# 2

# %%
letters = ["A","B","C","B"]

print(letters.index("B"))
# Out:
# 1

# %%
"""Internally , python performs 
for index, value in enumerate(list):
    if value == target:
        return index


"""
# Out:
# 'Internally , python performs \nfor index, value in enumerate(list):\n    if value == target:\n        return index\n\n\n'

# %% [markdown]
# Part 4 : count()

# %%
numbers = [10,20,20,20,30]

print(numbers.count(20))
# Out:
# 3
